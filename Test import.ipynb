# %%
import pickle
from TraitModel import *
from jupyterthemes import jtplot #внешний вид ноутбука и графиков
jtplot.style(theme='onedork')
# %matplotlib inline

# %%
with open('model_creation/models/model_logreg.pickle', 'rb') as f:
    model = pickle.load(f)

# %%
plot_traits(model, FMD, strict=True)

# %%
plot_traits(model, CHP, strict=True)

# %%
plot_traits(model, MY1, strict=True)

# %%
plot_traits(model, MY2, strict=True)

# %%
plot_traits(model, MY3, strict=True)

# %%
plot_traits(model, MY4, strict=True)

# %%
plot_traits(model, TI1, strict=True)
